# %%
import pandas as pd

# %%
denver_sales_df = pd.read_csv("real_property_sales_and_transfers.csv",low_memory=False)
res_char_df= pd.read_csv('real_property_residential_characteristics1.csv', low_memory=False)

# %%
# res_char_df.dtypes

# %%
denver_sales_df.head()
# Out:
#        SCHEDNUM  RECEPTION_NUM INSTRUMENT  SALE_YEAR  SALE_MONTHDAY  \
# 0  1.020100e+10     2018157240         WD       2018           1203
# 1  1.020101e+10     2018114222         WD       2018            906
# 2  1.020102e+10     2018073180         WD       2018            608
# 3  1.020102e+10     2018143037         WD       2018           1101
# 4  1.020104e+10     2018061274         WD       2018            521
#
#    RECEPTION_DATE  SALE_PRICE              GRANTOR  \
# 0        20181211      277696     ACOSTA,ANTHONY K
# 1        20180907      270000     GALLEGOS,PATRICK
# 2        20180613       50000  TLL INVESTMENTS LLC
# 3        20181105      230000          NELSON,NICK
# 4        20180523      242000        PHARRIS,DAVID
#
#                         GRANTEE CLASS  MKT_CLUS  D_CLASS   D_CLASS_CN  NBHD_1  \
# 0        VACHOVSKY FAMILY TRUST     H      52.0      193     ROWHOUSE       4
# 1          POUNDS,CHRISTOPHER L     H      52.0      193     ROWHOUSE       4
# 2                   NELSON,NICK     O      41.0      103  CONDOMINIUM       4
# 3  NEW DIRECTION TR COMPANY FBO     O      41.0      103  CONDOMINIUM       4
# 4           HAMMOND,FLORVIOLETA     O      41.0      103  CONDOMINIUM       4
#
#       NBHD_1_CN        PIN
# 0  GREEN VALLEY  163087844
# 1  GREEN VALLEY  163087941
# 2  GREEN VALLEY  163341651
# 3  GREEN VALLEY  163341651
# 4  GREEN VALLEY  163400101

# %%
# THIS STARTS ONE HOT ENCODING. SPECIFYING THE FEATURE I CARE ABOUT  
z = denver_sales_df.D_CLASS_CN

# %%
from sklearn.preprocessing import LabelEncoder
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(z)
encoded_z = label_encoder.transform(z)

# %%
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
one_hot_z = to_categorical(encoded_z)
dclass_encoded_df = pd.DataFrame(one_hot_z)
denver_sales_df['CONDO'] = dclass_encoded_df[0]
denver_sales_df['ROW_HOUSE'] = dclass_encoded_df[1]
denver_sales_df['SINGLE_FAMILY'] = dclass_encoded_df[2]

# %%
# res_char_df.head(5)

# %%
sales_res_char_df = pd.merge(denver_sales_df,res_char_df[['PIN','AREA_ABG','BED_RMS','FULL_B','HLF_B','CCYRBLT','LAND_SQFT']],how='inner',on='PIN')

sales_res_char_df.head()
# Out:
#        SCHEDNUM  RECEPTION_NUM INSTRUMENT  SALE_YEAR  SALE_MONTHDAY  \
# 0  1.020100e+10     2018157240         WD       2018           1203
# 1  1.020101e+10     2018114222         WD       2018            906
# 2  1.020102e+10     2018073180         WD       2018            608
# 3  1.020102e+10     2018143037         WD       2018           1101
# 4  1.020104e+10     2018061274         WD       2018            521
#
#    RECEPTION_DATE  SALE_PRICE              GRANTOR  \
# 0        20181211      277696     ACOSTA,ANTHONY K
# 1        20180907      270000     GALLEGOS,PATRICK
# 2        20180613       50000  TLL INVESTMENTS LLC
# 3        20181105      230000          NELSON,NICK
# 4        20180523      242000        PHARRIS,DAVID
#
#                         GRANTEE CLASS    ...            PIN  CONDO ROW_HOUSE  \
# 0        VACHOVSKY FAMILY TRUST     H    ...      163087844    0.0       1.0
# 1          POUNDS,CHRISTOPHER L     H    ...      163087941    0.0       1.0
# 2                   NELSON,NICK     O    ...      163341651    1.0       0.0
# 3  NEW DIRECTION TR COMPANY FBO     O    ...      163341651    1.0       0.0
# 4           HAMMOND,FLORVIOLETA     O    ...      163400101    1.0       0.0
#
#    SINGLE_FAMILY AREA_ABG  BED_RMS  FULL_B  HLF_B  CCYRBLT  LAND_SQFT
# 0            0.0     1716        3     2.0    1.0   2003.0       2760
# 1            0.0     1540        3     2.0    1.0   2003.0       1840
# 2            0.0     1226        2     2.0    1.0   2005.0       3617
# 3            0.0     1226        2     2.0    1.0   2005.0       3617
# 4            0.0     1226        2     2.0    1.0   2006.0       3617
#
# [5 rows x 25 columns]

# %%
sales_res_char_df['AGE'] = 2019 - sales_res_char_df['CCYRBLT']
sales_res_char_df.head()
# Out:
#        SCHEDNUM  RECEPTION_NUM INSTRUMENT  SALE_YEAR  SALE_MONTHDAY  \
# 0  1.020100e+10     2018157240         WD       2018           1203
# 1  1.020101e+10     2018114222         WD       2018            906
# 2  1.020102e+10     2018073180         WD       2018            608
# 3  1.020102e+10     2018143037         WD       2018           1101
# 4  1.020104e+10     2018061274         WD       2018            521
#
#    RECEPTION_DATE  SALE_PRICE              GRANTOR  \
# 0        20181211      277696     ACOSTA,ANTHONY K
# 1        20180907      270000     GALLEGOS,PATRICK
# 2        20180613       50000  TLL INVESTMENTS LLC
# 3        20181105      230000          NELSON,NICK
# 4        20180523      242000        PHARRIS,DAVID
#
#                         GRANTEE CLASS  ...   CONDO  ROW_HOUSE SINGLE_FAMILY  \
# 0        VACHOVSKY FAMILY TRUST     H  ...     0.0        1.0           0.0
# 1          POUNDS,CHRISTOPHER L     H  ...     0.0        1.0           0.0
# 2                   NELSON,NICK     O  ...     1.0        0.0           0.0
# 3  NEW DIRECTION TR COMPANY FBO     O  ...     1.0        0.0           0.0
# 4           HAMMOND,FLORVIOLETA     O  ...     1.0        0.0           0.0
#
#    AREA_ABG BED_RMS  FULL_B  HLF_B  CCYRBLT  LAND_SQFT   AGE
# 0      1716       3     2.0    1.0   2003.0       2760  16.0
# 1      1540       3     2.0    1.0   2003.0       1840  16.0
# 2      1226       2     2.0    1.0   2005.0       3617  14.0
# 3      1226       2     2.0    1.0   2005.0       3617  14.0
# 4      1226       2     2.0    1.0   2006.0       3617  13.0
#
# [5 rows x 26 columns]

# %%
grouped_neighborhoods = sales_res_char_df.groupby('NBHD_1_CN')

# %%
newdf = grouped_neighborhoods.count().reset_index()
neighborhoods = pd.Series(newdf.NBHD_1_CN)
neighborhoods[2]
# Out:
# 'AURARIA'

# %%
neighborhoods.head()
# Out:
# 0    ARAPAHOE SQUARE
# 1        ATHMAR PARK
# 2            AURARIA
# 3           BALLPARK
# 4             BARNUM
# Name: NBHD_1_CN, dtype: object

# %%
# THIS CODE WAS TESTING EXPORTING EACH NEW DATAFRAME IN THE FOR LOOP TO CSV.  THIS WORKED.
# for neighborhood in neighborhoods:
#     pd.DataFrame(sales_res_char_df.set_index('NBHD_1_CN').filter(like=neighborhood,axis=0)).to_csv(f"{neighborhood}.csv")

# %%
# DON'T NEED THIS CODE
# features_df = pd.DataFrame(sales_res_char_df,columns=['NBHD_1_CN','PIN','SALE_PRICE','SALE_YEAR','AREA_ABG','BED_RMS','FULL_B','HLF_B','CCYRBLT','LAND_SQFT','D_CLASS_CN','CONDO','ROW_HOUSE','SINGLE_FAMILY'])
# features_df['AGE'] = 2019 - features_df['CCYRBLT']
# features_df.head()

# %%
results_df = []
for neighborhood_name in neighborhoods:
#     print(f'Now training for {neighborhood_name} ')
    neighborhood_df = sales_res_char_df.set_index('NBHD_1_CN').loc[neighborhood_name]#pd.DataFrame(.filter(like=neighborhood,axis=0))
#     sales_res_char_df.set_index('NBHD_1_CN').loc[neighborhood_name].to_csv(f'Neighborhood_Sales/{neighborhood_name}.csv')
    y = neighborhood_df.SALE_PRICE.values.reshape(-1, 1)
    X = neighborhood_df[['AREA_ABG','BED_RMS','AGE','FULL_B','LAND_SQFT','CONDO','ROW_HOUSE','SINGLE_FAMILY']]
    from sklearn.datasets import make_regression
    from sklearn.linear_model import LinearRegression
    model = LinearRegression()
    model.fit(X,y)
#     from joblib import dump
#     dump(model, f'{neighborhood_name}.joblib')
#     results_df.append([neighborhood_name,model.score(X,y)], ignore_index=True)
    results_df.append([neighborhood_name,model.score(X,y)])

# %%
pd.DataFrame(results_df,columns=['Neiborhood','Score']).head()#.to_csv('Neighborhood_results.csv')
# Out:
#         Neiborhood     Score
# 0  ARAPAHOE SQUARE  0.734880
# 1      ATHMAR PARK  0.342825
# 2          AURARIA  0.964119
# 3         BALLPARK  0.951659
# 4           BARNUM  0.213990

# %%
sales_res_char_df.set_index('NBHD_1_CN').loc['MONTBELLO']

# %%
from sklearn.metrics import mean_squared_error, r2_score
predicted = model.predict(X)
mse = mean_squared_error(y, predicted)
r2 = r2_score(y, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")

# %%
model.score(X, y)

# %%
predictions = model.predict(X)
# Plot Residuals
plt.scatter(predictions, predictions - y)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.show()

# %%
from joblib import dump, load
dump(model,'Stapleton.joblib')

# %%
model.coef_

# %%
results = pd.DataFrame(columns=['Neighborhood','R2'])
from sklearn.linear_model import LinearRegression
# # for neighborhood_name in neighborhoods.head(1):
from joblib import load
#     neighborhood_name = load(f'Models/{neighborhood_name}.joblib')
#     print(neighborhood_name.score)
Academy = load('Models/Academy.joblib')
Academy.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}
